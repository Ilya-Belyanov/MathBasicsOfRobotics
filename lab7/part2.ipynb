# %% [markdown]
# ## Алгоритм перемещения робота по потенциальному полю

# %% [markdown]
# #### Импорты

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

from src.potensialfield import GradientBasedPlanner
from src.loaders import loadMatrix
from src.routecommon import startAndEntToMap, routeToMap

# %% [markdown]
# #### Входные параметры

# %%
start = [350, 50]
goal = [50, 400]
f = loadMatrix(os.getcwd() + "\\data\\f.txt")

# %% [markdown]
# #### Построение маршрута

# %%
route = GradientBasedPlanner(f, start, goal, 1000)

# %% [markdown]
# #### Отображение матрицы потенциалов и перемещения робота

# %%
map_with_start_end = startAndEntToMap(f, start, goal)
plt.matshow(map_with_start_end)
plt.scatter(start[1], start[0], s=50, color='black')
plt.scatter(goal[1], goal[0], s=50, color='white')
plt.plot(np.array(route)[:, 1], np.array(route)[:, 0], color='r')
plt.show()
